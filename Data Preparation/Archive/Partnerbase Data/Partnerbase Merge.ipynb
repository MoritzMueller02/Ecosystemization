# %%
import pandas as pd
df6_10 = pd.read_csv("DPE Research 6-10 Partner.csv", index_col=None)
df11_101 = pd.read_csv("DPE Research 11-101 Partner.csv", index_col=None)
df101_1000 = pd.read_csv("DPE Research 101-1000 Partner.csv", index_col=None)
df1000 = pd.read_csv("DPE Research 1000+Partner.csv", index_col=None)

# %%
partnerbase_df = pd.concat([df6_10, df11_101, df101_1000, df1000])

# %%
# Out:
#                     Company                                          Industry  \
# 0                  [24]7.ai                                          Software
# 1                    AbbVie                                    Pharmaceutical
# 2                       ABC                    Social Media, Media Production
# 3   Academy Sports Outdoors                                            Retail
# 4              ACCOR HOTELS                     Publishing , Public Relations
# ..                      ...                                               ...
# 10                  Red Hat                                          Software
# 11               Salesforce                                          Internet
# 12                      SAP                                          Software
# 13        Symantec CloudSOC  Software, Information Technology, Cyber Security
# 14                   VMware                                          Software
#
#     Founded  Number of Partners
# ...
